# %% [markdown]
# <a href="https://colab.research.google.com/github/ANANTH3011/Projects/blob/main/Credit_card_approval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Credit Card Approval:

# %% [markdown]
# ##Introduction:
#
# In the modern banking landscape, credit card approval prediction plays a pivotal role in maintaining a healthy financial ecosystem. The ability to accurately predict whether a potential client is desirable for a credit card can significantly impact a bank's risk management, profitability, and customer satisfaction. This project aims to utilize machine learning techniques to predict credit card approval based on customer information, thereby assisting banks in making informed decisions and reducing potential risks.

# %% [markdown]
# ###Importance in Today's World:
#
# In today's data-driven world, the volume of credit card applications and the complexity of customer profiles have increased. Traditional assessment methods may not suffice. Predictive models offer a more precise evaluation of applicants, considering a wide array of attributes, thus aligning with modern banking needs.

# %% [markdown]
# ###Impact on the Banking Sector:
#
# The implementation of accurate credit card approval prediction models can revolutionize the banking sector in various ways:
#
# 1. **Risk Management:** Banks can minimize default risks by identifying and approving clients with strong credit profiles.
#
# 2. **Efficiency:** Automated credit approval processes save time and resources compared to manual evaluations.
#
# 3. **Personalization:** Tailored credit decisions based on individual profiles lead to a better customer experience.
#
# 4. **Innovation:** The use of machine learning fosters innovation in banking practices, setting new standards for customer-centric solutions.

# %% [markdown]
# ###Gap in Knowledge and Future Relevance:
#
# While credit scoring models exist, incorporating external data sources and advanced machine learning techniques can further improve the accuracy and robustness of credit card approval predictions. This method can offer a more comprehensive understanding of an applicant's financial behavior, bridging potential gaps in the existing credit evaluation framework.

# %% [markdown]
# ##Initial Hypotheses:
#
# In this section, we will formulate some initial hypotheses to guide our data analysis and machine learning approach:
#
# 1. The applicant's credit history, including their Credit Bureau Score, will have a significant impact on the credit card approval decision.
#
# 2. Employment status and income level will influence the likelihood of credit card approval, with employed individuals and higher income earners being more likely to get approved.
#
# 3. Demographic factors such as age and marital status may also play a role in the credit card approval decision.
#
# 4. Existing relationship with the bank (e.g., having other accounts) might positively influence the credit card approval chances.
#
# 5. External data sources, such as social media behavior or online presence, could provide additional insights into an applicant's creditworthiness.

# %% [markdown]
# ##Data Analysis Approach
#
# Following the provided dataset, the data analysis approach remains consistent:
#
# 1. Exploratory Data Analysis (EDA): Visualize distributions of features like annual income, family size, and others, considering differences between approved and rejected applications.
#
# 2. Feature Engineering: Continue preprocessing with imputation, encoding, and normalization.
#
# 3. Data Splitting: Maintain the division of the dataset into training and testing sets for model evaluation.
#
# 4. Model Selection: The chosen classification models are : Random Forest, XGBoost, Logistic Regression, KNeighbors, and Decision Tree.
#
# 5. Model Training and Evaluation: Retrain models with the provided results and evaluate using metrics like accuracy, precision, recall and F1-score.

# %% [markdown]
# ##Machine Learning Approach
#
# The credit card approval prediction task is fundamentally a classification problem. To address this, we will evaluate a range of machine learning models to determine which ones are most effective for this particular task:
#
# ***Random Forest Classifier:*** Anticipated high accuracy and recall due to its ensemble nature.
#
# ***XGB Classifier:*** Expected to excel in accuracy and recall as well.
#
# ***Logistic Regression:*** Predicted lower accuracy and precision due to its linear nature.
#
# ***KNeighbors Classifier:*** Expected to have lower precision due to its sensitivity to noise.
#
# ***Decision Tree Classifier:*** The model's accuracy might be between Random Forest and Logistic Regression, reflecting its middle-ground nature.

# %% [markdown]
# ##Comparison of Models:
#
# Models will be compared based on various metrics, including accuracy, precision, recall and F1-score. This comprehensive evaluation will justify the superiority of specific models.
#
# By executing this approach on the dataset, we aim to develop a credit card approval prediction model that surpasses traditional credit scoring methods and offers valuable insights to the banking sector's decision-making process.

# %% [markdown]
# ##Information about dataset : Credit_Card.csv
#
# 1. Ind_ID: Client ID
#
# 2. Gender: Gender information
#
# 3. Car_owner: Having car or not
#
# 4. Propert_owner: Having property or not
#
# 5. Children: Count of children
#
# 6. Annual_income: Annual income
#
# 7. Type_Income: Income type
#
# 8. Education: Education level
#
# 9. Marital_status: Marital_status
#
# 10. Housing_type: Living style
#
# 11. Birthday_count: Use backward count from current day (0), -1 means yesterday.
#
# 12. Employed_days: Start date of employment. Use backward count from current day (0). Positive value means, individual is currently unemployed.
#
# 13. Mobile_phone: Any mobile phone
#
# 14. Work_phone: Any work phone
# 15. Phone: Any phone number
#
# 16. EMAIL_ID: Any email ID
#
# 17. Type_Occupation: Occupation
#
# 18. Family_Members: Family size
#
#
# ###Information about another dataset : Credit_card_label.csv
#
# 1. ID: The joining key between application data and credit status data, same is Ind_ID
#
# 2. Label: 0 is application approved and 1 is application rejected.

# %% [markdown]
# ## Data Collection :

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the 'Credit_card.csv' and 'Credit_card_label.csv' files into DataFrames
Credit_card = pd.read_csv('Credit_card.csv')
Credit_card_label = pd.read_csv('Credit_card_label.csv')

# Merging the 'Credit_card' dataset with the 'Credit_card_label' dataset using the 'Ind_ID' column to new dataset 'Credit_Card_approved'
# The 'inner' join ensures that only the rows with matching 'Ind_ID' values are included
Credit_Card_approved = Credit_card.merge(Credit_card_label, on='Ind_ID', how='inner')


# Merged dataset
Credit_Card_approved
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %% [markdown]
# ##Exploratory Data Analysis (EDA) :

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Create a figure and axis for the plot
fig, ax = plt.subplots()

# Create a bar plot using seaborn
sns.barplot(x='GENDER', y='Annual_income', data=Credit_Card_approved)

# Display the plot
plt.show()

# %%
sns.barplot(x='Car_Owner', y='Annual_income', data=Credit_Card_approved)

plt.show()

# %%
sns.barplot(x='Propert_Owner',y='Annual_income', data=Credit_Card_approved)

plt.show()

# %%
# Create a bar plot using seaborn
ax = sns.barplot(x='Type_Income', y='Annual_income', data=Credit_Card_approved)

# Changing the font size of x-axis labels
ax.set_xticklabels(ax.get_xticklabels(), fontsize=8)

# Display the plot
plt.show()

# %%
ax = sns.barplot(x='EDUCATION',y='Annual_income', data=Credit_Card_approved)

ax.set_xticklabels(ax.get_xticklabels(), fontsize=5)

plt.show()

# %%
ax = sns.barplot(x='Marital_status',y='Annual_income', data=Credit_Card_approved)

ax.set_xticklabels(ax.get_xticklabels(), fontsize=8)

plt.show()

# %% [markdown]
# ## Feature Engineering:

# %% [markdown]
# ### Finding Null Values In Dataset

# %%
Credit_Card_approved.info() #To check the datatype of the each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
# Check for missing values in the 'Credit_Card_approved' DataFrame and calculate the sum of missing values for each column
Credit_Card_approved.isnull().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
# Calculate Age based on Birthday_count
Credit_Card_approved['Age']=-(Credit_Card_approved['Birthday_count'])//365

# Drop rows with missing values in specific columns: 'Annual_income', 'GENDER', 'Birthday_count'
Credit_Card_approved = Credit_Card_approved.dropna(subset=['Annual_income', 'GENDER','Birthday_count'])

# Drop unnecessary columns: 'Mobile_phone', 'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Birthday_count'
Credit_Card_approved = Credit_Card_approved.drop(['Mobile_phone','Work_Phone','Phone','EMAIL_ID','Type_Occupation','Birthday_count'],axis=1)

Credit_Card_approved

# Create a new column 'Employment_Status' based on 'Employed_days' indicating employment status
Credit_Card_approved['Employment_Status'] = Credit_Card_approved['Employed_days'].apply(lambda x: 1 if x < 0 else 0)

# There are many incorrect values in 'Employed_days'. Therefore, keeping rows where 'Employed_days' is less than or equal to 365000
Credit_Card_approved = Credit_Card_approved[Credit_Card_approved['Employed_days'] <= 365000]

# Droping the column 'Employed_days'
Credit_Card_approved = Credit_Card_approved.drop(['Employed_days'],axis=1)

Credit_Card_approved
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 1     5009744      F         Y             N         0       315000.0
# 4     5009752      F         Y             N         0       315000.0
# 6     5009754      F         Y             N         0       315000.0
# 8     5010864      M         Y             Y         1       450000.0
# 9     5010868      M         Y             Y         1       450000.0
# ...       ...    ...       ...           ...       ...            ...
# 1542  5118268      M         Y             N         1       360000.0
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 1     Commercial associate               Higher education
# ...

# %% [markdown]
# ### Convert Categorical Variables into Numerical Values :

# %%
Credit_Card_approved.info()   # Checking if the datatypes are matching with individual column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1244 entries, 1 to 1547
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ind_ID             1244 non-null   int64
#  1   GENDER             1244 non-null   object
#  2   Car_Owner          1244 non-null   object
#  3   Propert_Owner      1244 non-null   object
#  4   CHILDREN           1244 non-null   int64
#  5   Annual_income      1244 non-null   float64
#  6   Type_Income        1244 non-null   object
#  7   EDUCATION          1244 non-null   object
#  8   Marital_status     1244 non-null   object
#  9   Housing_type       1244 non-null   object
#  10  Family_Members     1244 non-null   int64
#  11  label              1244 non-null   int64
#  12  Age                1244 non-null   float64
#  13  Employment_Status  1244 non-null   int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 145.8+ KB

# %%
#In the info we can see that columns : 'GENDER','Car_Owner','Propert_Owner,'Type_Income','EDUCATION','Marital_status','Housing_type' are categorical features.
#Now we have to covert them into numerical values using Pandas get dummies

# Performing one-hot encoding on selected categorical columns
Credit_Card_approved = pd.get_dummies(Credit_Card_approved, columns=['GENDER', 'Car_Owner', 'Propert_Owner', 'Type_Income', 'EDUCATION', 'Marital_status', 'Housing_type'])

Credit_Card_approved
# Out:
#        Ind_ID  CHILDREN  Annual_income  Family_Members  label   Age  \
# 1     5009744         0       315000.0               2      1  37.0
# 4     5009752         0       315000.0               2      1  37.0
# 6     5009754         0       315000.0               2      1  37.0
# 8     5010864         1       450000.0               3      1  49.0
# 9     5010868         1       450000.0               3      1  49.0
# ...       ...       ...            ...             ...    ...   ...
# 1542  5118268         1       360000.0               3      0  30.0
# 1544  5023655         0       225000.0               1      0  28.0
# 1545  5115992         2       180000.0               4      0  36.0
# 1546  5118219         0       270000.0               2      0  41.0
# 1547  5053790         0       225000.0               2      0  45.0
#
#       Employment_Status  GENDER_F  GENDER_M  Car_Owner_N  ...  \
# 1                     1         1         0            0  ...
# ...

# %% [markdown]
# ### Log Transformation :

# %%
# Create a histogram plot of 'Annual_income'
sns.histplot(Credit_Card_approved['Annual_income'], kde=True, bins=25, color='blue', edgecolor='black')

# Display the plot
plt.show()

# %%
import numpy as np

# Applying the natural logarithm transformation to normalize our target variable 'Annual_income'
Credit_Card_approved['Annual_income'] = np.log(Credit_Card_approved['Annual_income'])

Credit_Card_approved
# Out:
#        Ind_ID  CHILDREN  Annual_income  Family_Members  label   Age  \
# 1     5009744         0      12.660328               2      1  37.0
# 4     5009752         0      12.660328               2      1  37.0
# 6     5009754         0      12.660328               2      1  37.0
# 8     5010864         1      13.017003               3      1  49.0
# 9     5010868         1      13.017003               3      1  49.0
# ...       ...       ...            ...             ...    ...   ...
# 1542  5118268         1      12.793859               3      0  30.0
# 1544  5023655         0      12.323856               1      0  28.0
# 1545  5115992         2      12.100712               4      0  36.0
# 1546  5118219         0      12.506177               2      0  41.0
# 1547  5053790         0      12.323856               2      0  45.0
#
#       Employment_Status  GENDER_F  GENDER_M  Car_Owner_N  ...  \
# 1                     1         1         0            0  ...
# ...

# %%
sns.histplot(Credit_Card_approved['Annual_income'], kde=True, bins=25, color='blue', edgecolor='black')

plt.show()

# %% [markdown]
# ### Dealing with Outliers :

# %%
# List of columns to create box plots to check for any outliers:
columns_to_plot = ['Ind_ID', 'CHILDREN', 'Annual_income', 'Family_Members', 'Age']

# Loop through each column and create box plots
for column in columns_to_plot:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=Credit_Card_approved, x=column)
    plt.title(f'Box Plot of {column}')
    plt.xticks(rotation=45)
    plt.show()

#We are having outliers in 'CHILDREN', 'Family_Members','Annual_income'
#Now, we have to remove the outlier to build a better result.

# %%
import pandas as pd

# Load your dataset into the Credit_Card_approved DataFrame
# Replace with the actual data source

# Calculate the IQR for 'CHILDREN', 'Family_Members', and 'Annual_income'
columns_to_check = ['CHILDREN', 'Family_Members', 'Annual_income']

for column in columns_to_check:
    Q1 = Credit_Card_approved[column].quantile(0.25)
    Q3 = Credit_Card_approved[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define lower and upper bounds to identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Remove outliers from the column
    Credit_Card_approved = Credit_Card_approved[(Credit_Card_approved[column] >= lower_bound) & (Credit_Card_approved[column] <= upper_bound)]

# Print the updated dataset
print(Credit_Card_approved)
# Out:
#        Ind_ID  CHILDREN  Annual_income  Family_Members  label   Age  \
# 1     5009744         0      12.660328               2      1  37.0
# 4     5009752         0      12.660328               2      1  37.0
# 6     5009754         0      12.660328               2      1  37.0
# 8     5010864         1      13.017003               3      1  49.0
# 9     5010868         1      13.017003               3      1  49.0
# ...       ...       ...            ...             ...    ...   ...
# 1542  5118268         1      12.793859               3      0  30.0
# 1544  5023655         0      12.323856               1      0  28.0
# 1545  5115992         2      12.100712               4      0  36.0
# 1546  5118219         0      12.506177               2      0  41.0
# 1547  5053790         0      12.323856               2      0  45.0
#
#       Employment_Status  GENDER_F  GENDER_M  Car_Owner_N  ...  \
# 1                     1         1         0            0  ...
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns to create box plots for
columns_to_plot = ['Ind_ID', 'CHILDREN', 'Annual_income', 'Family_Members', 'Age']

# Loop through each column and create a box plot
for column in columns_to_plot:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=Credit_Card_approved, x=column)
    plt.title(f'Box Plot of {column}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Data Splitting:

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# Split the data into features (X) and target (y)
X = Credit_Card_approved.drop('label', axis=1)
y = Credit_Card_approved['label']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (960, 32)
# (960,)

# %% [markdown]
# ### Model Training and Evaluation :

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

### Crating a standard scaler object
scaler=StandardScaler()

### using fit_transform to Standardize the train data
X_train=scaler.fit_transform(X_train)

### here using transform only to avoid data leakage
### (training mean and training std will be used for standardisation when we use transform)
X_test=scaler.transform(X_test)

random_forest = RandomForestClassifier()

random_forest.fit(X_train, y_train)

# Make predictions using the Random Forest Classifier
y_pred_random_forest = random_forest.predict(X_test)

# Calculate the evaluation metrics for Random Forest Classifier
accuracy_random_forest = accuracy_score(y_test, y_pred_random_forest)
precision_random_forest = precision_score(y_test, y_pred_random_forest)
recall_random_forest = recall_score(y_test, y_pred_random_forest)
f1_random_forest = f1_score(y_test, y_pred_random_forest)

# Print the evaluation metrics for Random Forest Classifier
print("Random Forest Classifier:")
print("Accuracy:", accuracy_random_forest)
print("Precision:", precision_random_forest)
print("Recall:", recall_random_forest)
print("F1 Score:", f1_random_forest)
# Out:
# Random Forest Classifier:
# Accuracy: 0.9375
# Precision: 0.7272727272727273
# Recall: 0.4
# F1 Score: 0.5161290322580645

# %%
import xgboost as xgb
### Crating a standard scaler object
scaler=StandardScaler()

### using fit_transform to Standardize the train data
X_train=scaler.fit_transform(X_train)

### here using transform only to avoid data leakage
### (training mean and training std will be used for standardisation when we use transform)
X_test=scaler.transform(X_test)

xgboost = xgb.XGBClassifier()

xgboost.fit(X_train, y_train)

y_pred_xgboost = xgboost.predict(X_test)

# Evaluate the model
accuracy_xgboost = accuracy_score(y_test, y_pred_xgboost)
precision_xgboost = precision_score(y_test, y_pred_xgboost)
recall_xgboost = recall_score(y_test, y_pred_xgboost)
f1_xgboost = f1_score(y_test, y_pred_xgboost)

print("XGB Classifier :")
print("Accuracy :", accuracy_xgboost)
print("Precision:", precision_xgboost)
print("Recall   :", recall_xgboost)
print("F1 Score :", f1_xgboost)
# Out:
# XGB Classifier :
# Accuracy : 0.9333333333333333
# Precision: 0.6666666666666666
# Recall   : 0.4
# F1 Score : 0.5

# %%
from sklearn.linear_model import LogisticRegression

### Crating a standard scaler object
scaler=StandardScaler()

### using fit_transform to Standardize the train data
X_train=scaler.fit_transform(X_train)

### here using transform only to avoid data leakage
### (training mean and training std will be used for standardisation when we use transform)
X_test=scaler.transform(X_test)

### Creating a Logistic regression object
logistic_reg=LogisticRegression()

logistic_reg.fit(X_train,y_train)

logistic_reg_pred=logistic_reg.predict(X_test)

accuracy_lr = accuracy_score(y_test, logistic_reg_pred)
precision_lr = precision_score(y_test, logistic_reg_pred)
recall_lr = recall_score(y_test, logistic_reg_pred)
f1_lr = f1_score(y_test, logistic_reg_pred)

print("Logistic Regression :")
print("Accuracy     :", accuracy_lr)
print("Precision    :", precision_lr)
print("Recall       :", recall_lr)
print("F1 Score     :", f1_lr)
# Out:
# Logistic Regression :
# Accuracy     : 0.9166666666666666
# Precision    : 0.5
# Recall       : 0.05
# F1 Score     : 0.09090909090909091

# %%
from sklearn.neighbors import KNeighborsClassifier

### Crating a standard scaler object
scaler=StandardScaler()

### using fit_transform to Standardize the train data
X_train=scaler.fit_transform(X_train)

### here using transform only to avoid data leakage
### (training mean and training std will be used for standardisation when we use transform)
X_test=scaler.transform(X_test)

knn = KNeighborsClassifier()

knn.fit(X_train, y_train)

# Make predictions on the test set
y_pred_knn = knn.predict(X_test)

# Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn)
recall_knn = recall_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn)

# Print the evaluation metrics
print("KNeighbors Classifier:")
print("Accuracy:", accuracy_knn)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1 Score:", f1_knn)
# Out:
# KNeighbors Classifier:
# Accuracy: 0.9083333333333333
# Precision: 0.3333333333333333
# Recall: 0.1
# F1 Score: 0.15384615384615383

# %%
from sklearn.tree import DecisionTreeClassifier

### Crating a standard scaler object
scaler=StandardScaler()

### using fit_transform to Standardize the train data
X_train=scaler.fit_transform(X_train)

### here using transform only to avoid data leakage
### (training mean and training std will be used for standardisation when we use transform)
X_test=scaler.transform(X_test)

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)

# Make predictions on the test set
y_pred_dt = dt.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
precision_dt = precision_score(y_test, y_pred_dt)
recall_dt = recall_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt)

# Print the evaluation metrics
print("Decision Tree Classifier :")
print("Accuracy:", accuracy_dt)
print("Precision:", precision_dt)
print("Recall:", recall_dt)
print("F1 Score:", f1_dt)
# Out:
# Decision Tree Classifier :
# Accuracy: 0.875
# Precision: 0.32142857142857145
# Recall: 0.45
# F1 Score: 0.375

# %%
from tabulate import tabulate

data = {
    'Model': ['Random Forest Classifier','XGB Classifier','Logistic Regression','KNeighbors Classifier' , 'Decision Tree Classifier' ],
    'Accuracy': [accuracy_random_forest,accuracy_xgboost,accuracy_lr, accuracy_knn,accuracy_dt],  # Fill in actual accuracy values
    'Precision': [precision_random_forest,precision_xgboost,precision_lr,precision_knn,precision_dt,],  # Fill in actual precision values
    'Recall': [recall_random_forest,recall_xgboost,recall_lr,recall_knn,recall_dt],  # Fill in actual recall values
    'F1 Score': [f1_random_forest,f1_xgboost,f1_lr,f1_knn,f1_dt]  # Fill in actual F1 score values
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

table = tabulate(df, headers='keys', tablefmt='grid')
# Print the DataFrame
print(table)
# Out:
# +----+--------------------------+------------+-------------+----------+------------+
# |    | Model                    |   Accuracy |   Precision |   Recall |   F1 Score |
# +====+==========================+============+=============+==========+============+
# |  0 | Random Forest Classifier |   0.9375   |    0.727273 |     0.4  |  0.516129  |
# +----+--------------------------+------------+-------------+----------+------------+
# |  1 | XGB Classifier           |   0.933333 |    0.666667 |     0.4  |  0.5       |
# +----+--------------------------+------------+-------------+----------+------------+
# |  2 | Logistic Regression      |   0.916667 |    0.5      |     0.05 |  0.0909091 |
# +----+--------------------------+------------+-------------+----------+------------+
# |  3 | KNeighbors Classifier    |   0.908333 |    0.333333 |     0.1  |  0.153846  |
# +----+--------------------------+------------+-------------+----------+------------+
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Model': ['Random Forest Classifier','XGB Classifier','Logistic Regression','KNeighbors Classifier' , 'Decision Tree Classifier' ],
    'Accuracy': [accuracy_random_forest,accuracy_xgboost,accuracy_lr, accuracy_knn,accuracy_dt],  # Fill in actual accuracy values
    'Precision': [precision_random_forest,precision_xgboost,precision_lr,precision_knn,precision_dt,],  # Fill in actual precision values
    'Recall': [recall_random_forest,recall_xgboost,recall_lr,recall_knn,recall_dt],  # Fill in actual recall values
    'F1 Score': [f1_random_forest,f1_xgboost,f1_lr,f1_knn,f1_dt]  # Fill in actual F1 score values
}

# Create a DataFrame from the dictionary
#df = pd.DataFrame(data)

# Set the style of seaborn
sns.set(style="whitegrid")

# Melt the DataFrame to create a "metric" column
df_melted = df.melt(id_vars=['Model'], var_name='Metric', value_name='Score')

# Create a bar plot with all metrics
plt.figure(figsize=(12, 8))
sns.barplot(x='Model', y='Score', hue='Metric', data=df_melted)
plt.xlabel('Model')
plt.ylabel('Score')
plt.title('Comparison of Evaluation Metrics for Different Models')
plt.xticks(rotation=45, ha='right')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights and Recommendations:
#
# 1. The ***Random Forest Classifier*** appears to be the ***best-performing model*** overall, with the highest accuracy and balanced precision-recall trade-off. It could be a strong candidate for predicting credit card approval.
# 2. The XGB Classifier also shows promise, but it might require hyperparameter tuning to improve both precision and recall.
# 3. Logistic Regression, KNeighbors Classifier, and Decision Tree Classifier have limitations in terms of precision and/or recall. Consider further improving these models or exploring different algorithms.
# 4. Depending on the business context, it might be crucial to focus on either precision or recall. For example, if the cost of false positives (approving a risky customer) is high, prioritize precision. If the cost of false negatives (rejecting a genuine customer) is high, prioritize recall.

# %% [markdown]
# Considering the available data, the ***Random Forest Classifier*** emerges as a more promising choice for credit card approval

# %% [markdown]
# #SQL

# %% [markdown]
# Use MySQL or PyMySQL to perform the below queries.
#
# Note: Use only the cleaned data for SQL part of the project

# %%
import pandas as pd
import sqlite3
from google.colab import drive
drive.mount('/content/drive')

def execute_query_on_csv(query):

# Path to the CSV file in your Google Drive
  csv_file_path = '/content/drive/MyDrive/Credit_Card_approved.csv'

# Read the CSV file into a pandas DataFrame
  data = pd.read_csv(csv_file_path)

# Create an in-memory SQLite database connection
  conn = sqlite3.connect(':memory:')

# Write the DataFrame into the SQLite database
  data.to_sql('credit_card_approved', conn, index=False)

# Execute the query and fetch results
  result = conn.execute(query)
  rows = result.fetchall()

# Close the connection
  conn.close()

# Print the fetched rows
  for row in rows:
      print(row)
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Group the customers based on their income type and find the average of their annual income.

# %%
query1 = '''
SELECT Type_Income, AVG(Annual_income) AS Avg_Annual_income
FROM credit_card_approved
GROUP BY Type_Income
ORDER BY Avg_Annual_income DESC
'''
execute_query_on_csv(query1)
# Out:
# ('Pensioner', 284142.85714285716)
# ('Commercial associate', 233880.1699716714)
# ('State servant', 210130.4347826087)
# ('Working', 180154.5799739922)

# %% [markdown]
# 2. Find the female owners of cars and property.

# %%
query2 = '''
SELECT Ind_ID, GENDER, Car_Owner, Propert_Owner
FROM credit_card_approved
WHERE GENDER = 'F' AND Car_Owner = 'Y' AND Propert_Owner = 'Y'
'''
execute_query_on_csv(query2)
# Out:
# (5018498, 'F', 'Y', 'Y')
# (5018503, 'F', 'Y', 'Y')
# (5024213, 'F', 'Y', 'Y')
# (5053254, 'F', 'Y', 'Y')
# (5065348, 'F', 'Y', 'Y')
# (5068389, 'F', 'Y', 'Y')
# (5069216, 'F', 'Y', 'Y')
# (5069218, 'F', 'Y', 'Y')
# (5125708, 'F', 'Y', 'Y')
# (5125716, 'F', 'Y', 'Y')
# (5143231, 'F', 'Y', 'Y')
# (5028917, 'F', 'Y', 'Y')
# (5095310, 'F', 'Y', 'Y')
# (5143235, 'F', 'Y', 'Y')
# (5054522, 'F', 'Y', 'Y')
# (5126034, 'F', 'Y', 'Y')
# (5139548, 'F', 'Y', 'Y')
# (5105614, 'F', 'Y', 'Y')
# (5009980, 'F', 'Y', 'Y')
# (5009074, 'F', 'Y', 'Y')
# (5023280, 'F', 'Y', 'Y')
# (5021267, 'F', 'Y', 'Y')
# (5090861, 'F', 'Y', 'Y')
# (5035688, 'F', 'Y', 'Y')
# (5078842, 'F', 'Y', 'Y')
# (5113291, 'F', 'Y', 'Y')
# (5139951, 'F', 'Y', 'Y')
# (5010397, 'F', 'Y', 'Y')
# (5047789, 'F', 'Y', 'Y')
# (5105657, 'F', 'Y', 'Y')
# (5088699, 'F', 'Y', 'Y')
# (5146472, 'F', 'Y', 'Y')
# (5135574, 'F', 'Y', 'Y')
# (5113132, 'F', 'Y', 'Y')
# (5062670, 'F', 'Y', 'Y')
# (5029544, 'F', 'Y', 'Y')
# (5111159, 'F', 'Y', 'Y')
# ...

# %% [markdown]
# 3. Find the male customers who are staying with their families.

# %%
query3 = '''
select Ind_ID,GENDER,Family_Members from credit_card_approved
where GENDER = 'M' and Family_Members > 1
'''
execute_query_on_csv(query3)
# Out:
# (5010864, 'M', 3)
# (5010868, 'M', 3)
# (5021303, 'M', 3)
# (5021310, 'M', 2)
# (5021314, 'M', 2)
# (5021998, 'M', 2)
# (5022617, 'M', 2)
# (5023781, 'M', 2)
# (5028580, 'M', 2)
# (5033916, 'M', 2)
# (5036469, 'M', 2)
# (5036590, 'M', 2)
# (5036795, 'M', 2)
# (5048300, 'M', 3)
# (5048301, 'M', 3)
# (5050603, 'M', 2)
# (5050606, 'M', 2)
# (5051160, 'M', 3)
# (5051161, 'M', 3)
# (5052877, 'M', 2)
# (5052879, 'M', 2)
# (5052882, 'M', 2)
# (5054063, 'M', 3)
# (5062136, 'M', 2)
# (5069307, 'M', 2)
# (5079166, 'M', 2)
# (5079167, 'M', 2)
# (5079168, 'M', 2)
# (5085886, 'M', 2)
# (5089959, 'M', 3)
# (5090214, 'M', 2)
# (5090216, 'M', 2)
# (5092087, 'M', 4)
# (5092479, 'M', 3)
# (5114249, 'M', 3)
# (5114253, 'M', 3)
# (5116906, 'M', 2)
# (5125763, 'M', 3)
# (5135344, 'M', 2)
# (5135345, 'M', 2)
# (5135346, 'M', 2)
# (5135636, 'M', 2)
# (5142184, 'M', 4)
# (5142185, 'M', 4)
# (5142361, 'M', 3)
# (5142362, 'M', 3)
# (5143342, 'M', 3)
# (5148932, 'M', 2)
# (5148934, 'M', 2)
# (5149188, 'M', 3)
# ...

# %% [markdown]
# 4. Please list the top five people having the highest income.

# %%
query4 = '''
select Ind_ID,GENDER,Annual_income,EDUCATION from credit_card_approved
where Annual_income >=(
select Annual_income from credit_card_approved
order by Annual_income desc
limit 1 offset 5)
'''
execute_query_on_csv(query4)
# Out:
# (5143231, 'F', 1575000.0, 'Higher education')
# (5143235, 'F', 1575000.0, 'Higher education')
# (5090470, 'M', 900000.0, 'Secondary / secondary special')
# (5079016, 'M', 900000.0, 'Higher education')
# (5079017, 'M', 900000.0, 'Higher education')
# (5116005, 'M', 900000.0, 'Higher education')

# %% [markdown]
# 5. How many married people are having bad credit?

# %%
query5 = '''
select count(*) as Count_of_married_people_having_bad_credit from credit_card_approved
where Marital_status in ('Married','Civil marriage') and label = 0
'''
execute_query_on_csv(query5)
# Out:
# (870,)

# %% [markdown]
# 6. What is the highest education level and what is the total count?

# %%
query6 = '''
SELECT EDUCATION, COUNT(*) AS Total_Counts
FROM credit_card_approved
GROUP BY EDUCATION
HAVING EDUCATION LIKE '%degree'
'''
execute_query_on_csv(query6)
# Out:
# ('Academic degree', 2)

# %% [markdown]
# 7. Between married males and females, who is having more bad credit?

# %%
query7 = '''
select GENDER,count(*) Bad_Credit from credit_card_approved
group by GENDER,label
having label = 0
order by Bad_Credit desc
limit 1
'''
execute_query_on_csv(query7)
# Out:
# ('F', 676)
